# %% [markdown]
# To determine if caffeine has a significant effect on reaction time, we can use a one-sample t-test. This test is appropriate as we are comparing the sample mean to a known value (which is usually the mean reaction time without caffeine, but let's assume it to be a certain value, such as 0.3 seconds, for the sake of this example).
#
# Steps for the Hypothesis Test:
#
# State the Hypotheses:
#
# Null Hypothesis (
# �
# 0
# H
# 0
# ​
#  ): The caffeine has no effect on reaction time. This would mean the mean reaction time is the same with or without caffeine. Assuming the mean without caffeine is 0.3 seconds,
# �
# 0
# :
# �
# =
# 0.3
# H
# 0
# ​
#  :μ=0.3.
# Alternative Hypothesis (
# �
# 1
# H
# 1
# ​
#  ): The caffeine does have an effect on reaction time. This would mean the mean reaction time is different from 0.3 seconds,
# �
# 1
# :
# �
# ≠
# 0.3
# H
# 1
# ​
#  :μ
# 
# =0.3.
# Set the Significance Level:
#
# A 90% confidence level means the significance level (
# �
# α) is 0.10 (100% - 90%).
# Calculate the Test Statistic:
#
# Use the t-statistic formula:
# �
# =
# �
# ˉ
# −
# �
# 0
# �
# /
# �
# t=
# s/
# n
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Where
# �
# ˉ
# x
# ˉ
#   is the sample mean,
# �
# 0
# μ
# 0
# ​
#   is the mean reaction time under the null hypothesis,
# �
# s is the sample standard deviation, and
# �
# n is the sample size.
# Plugging in the values:
# �
# =
# 0.25
# −
# 0.3
# 0.05
# /
# 30
# t=
# 0.05/
# 30
# ​
#
# 0.25−0.3
# ​
#
# �
# =
# −
# 0.05
# 0.05
# /
# 30
# t=
# 0.05/
# 30
# ​
#
# −0.05
# ​
#
# �
# ≈
# −
# 0.05
# 0.009128
# t≈
# 0.009128
# −0.05
# ​
#
# �
# ≈
# −
# 5.48
# t≈−5.48
# Determine the Critical t-value:
#
# For a two-tailed test at a 0.10 significance level with 29 degrees of freedom (since degrees of freedom =
# �
# −
# 1
# n−1), we can look up the critical value in a t-distribution table or use a calculator.
# Compare the Test Statistic to the Critical Value:
#
# If the absolute value of the calculated t-statistic is greater than the critical t-value, we reject the null hypothesis.
# Draw a Conclusion:
#
# Given that typical critical t-values for a two-tailed test with 29 degrees of freedom at a 0.10 significance level are around ±1.699, and our calculated t-value of approximately -5.48 is outside this range (i.e., the absolute value is greater than 1.699), we reject the null hypothesis.
# Conclusion:
# Based on this hypothesis test, we can conclude that there is statistically significant evidence at the 90% confidence level to suggest that caffeine does have a significant effect on reaction time, as the average reaction time in the sample (0.25 seconds) is significantly different from the assumed normal reaction time (0.3 seconds).
