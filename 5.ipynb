# %% [markdown]
# A confidence interval (CI) is a range of values, derived from sample statistics, that is likely to contain the value of an unknown population parameter. The confidence interval provides an estimated range of values which is likely to include an unknown population parameter, the estimated range being calculated from a given set of sample data.
#
# Key Points:
# Confidence Level: Typically expressed as a percentage (e.g., 90%, 95%, 99%). A 95% confidence interval, for example, implies that if we were to take 100 different samples and compute a CI for each sample, then approximately 95 of the 100 CIs will contain the true population parameter.
# Margin of Error: The range above and below the sample statistic. A smaller margin of error indicates a more precise estimate.
# Calculation of Confidence Interval:
# The formula for a confidence interval depends on several factors, including the sample size, the level of confidence you want to achieve, and whether you are working with means or proportions. The general formula for a confidence interval for a population mean, when the population standard deviation is known, is:
#
# CI
# =
# �
# ˉ
# ±
# �
# ×
# (
# �
# �
# )
# CI=
# x
# ˉ
#  ±Z×(
# n
# ​
#
# σ
# ​
#  )
#
# Where:
#
# �
# ˉ
# x
# ˉ
#   is the sample mean.
# �
# Z is the Z-value from the standard normal distribution corresponding to the desired confidence level (e.g., 1.96 for 95% confidence).
# �
# σ is the population standard deviation.
# �
# n is the sample size.
# Example:
# Suppose you have a sample of 30 students and their average test score is 78, with a population standard deviation of 10. You want to calculate a 95% confidence interval for the mean test score.
#
# Sample Mean (
# �
# ˉ
# x
# ˉ
#  ): 78
# Z-value for 95% confidence: Approximately 1.96 (This value comes from the standard normal distribution table).
# Population Standard Deviation (
# �
# σ): 10
# Sample Size (
# �
# n): 30
# Plug these values into the formula:
#
# CI
# =
# 78
# ±
# 1.96
# ×
# (
# 10
# 30
# )
# CI=78±1.96×(
# 30
# ​
#
# 10
# ​
#  )
#
# Calculate the margin of error:
#
# Margin of Error
# =
# 1.96
# ×
# (
# 10
# 30
# )
# ≈
# 3.58
# Margin of Error=1.96×(
# 30
# ​
#
# 10
# ​
#  )≈3.58
#
# So, the 95% confidence interval is:
#
# CI
# =
# 78
# ±
# 3.58
# CI=78±3.58
# CI
# =
# [
# 74.42
# ,
# 81.58
# ]
# CI=[74.42,81.58]
#
# This means we can be 95% confident that the true average test score of all students lies between 74.42 and 81.58.
