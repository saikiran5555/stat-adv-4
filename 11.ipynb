# %% [markdown]
# To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job, we can use the formula for the confidence interval of a proportion. The formula is:
#
# CI
# =
# �
# ^
# ±
# �
# ×
# �
# ^
# (
# 1
# −
# �
# ^
# )
# �
# CI=
# p
# ^
# ​
#  ±Z×
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
#
# Where:
#
# �
# ^
# p
# ^
# ​
#   is the sample proportion.
# �
# Z is the Z-value from the standard normal distribution for the desired confidence level (for 95%,
# �
# Z is approximately 1.96).
# �
# n is the sample size.
# Given:
#
# Sample Proportion (
# �
# ^
# p
# ^
# ​
#  ): 65% or 0.65
# Sample Size (n): 500
# Confidence Level: 95% (which gives us a Z-value of about 1.96)
# Step 1: Calculate the Standard Error (SE)
# �
# �
# =
# �
# ^
# (
# 1
# −
# �
# ^
# )
# �
# SE=
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
# �
# �
# =
# 0.65
# (
# 1
# −
# 0.65
# )
# 500
# SE=
# 500
# 0.65(1−0.65)
# ​
#
# ​
#
# �
# �
# =
# 0.65
# ×
# 0.35
# 500
# SE=
# 500
# 0.65×0.35
# ​
#
# ​
#
# �
# �
# =
# 0.2275
# 500
# SE=
# 500
# 0.2275
# ​
#
# ​
#
# �
# �
# =
# 0.000455
# SE=
# 0.000455
# ​
#
# �
# �
# ≈
# 0.0213
# SE≈0.0213
#
# Step 2: Calculate the Margin of Error
# Margin of Error
# =
# �
# ×
# �
# �
# Margin of Error=Z×SE
# Margin of Error
# =
# 1.96
# ×
# 0.0213
# Margin of Error=1.96×0.0213
# Margin of Error
# ≈
# 0.0417
# Margin of Error≈0.0417
#
# Step 3: Calculate the Confidence Interval
# CI
# =
# �
# ^
# ±
# Margin of Error
# CI=
# p
# ^
# ​
#  ±Margin of Error
# CI
# =
# 0.65
# ±
# 0.0417
# CI=0.65±0.0417
# CI
# =
# [
# 0.65
# −
# 0.0417
# ,
# 0.65
# +
# 0.0417
# ]
# CI=[0.65−0.0417,0.65+0.0417]
# CI
# =
# [
# 0.6083
# ,
# 0.6917
# ]
# CI=[0.6083,0.6917]
#
# Interpretation:
# The 95% confidence interval for the true proportion of people who are satisfied with their job is from approximately 60.83% to 69.17%. This means we can be 95% confident that the true proportion of job satisfaction in the population falls within this range.
