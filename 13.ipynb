# %% [markdown]
# To calculate the 90% confidence interval for the true population mean, we use the formula for a confidence interval when the population standard deviation is known. This scenario is appropriate for a z-test because we are dealing with a known population standard deviation. The formula for the confidence interval is:
#
# CI
# =
# �
# ˉ
# ±
# �
# ×
# (
# �
# �
# )
# CI=
# x
# ˉ
#  ±Z×(
# n
# ​
#
# σ
# ​
#  )
#
# Where:
#
# �
# ˉ
# x
# ˉ
#   is the sample mean.
# �
# Z is the Z-value from the standard normal distribution corresponding to the desired confidence level (for 90%, it's typically around 1.645).
# �
# σ is the population standard deviation.
# �
# n is the sample size.
# Given:
#
# Population Mean (not used in this calculation): 60
# Population Standard Deviation (
# �
# σ): 8
# Sample Mean (
# �
# ˉ
# x
# ˉ
#  ): 65
# Sample Size (n): 50
# Confidence Level: 90%
# Step 1: Determine the Z-value
# For a 90% confidence interval, the Z-value is approximately 1.645.
#
# Step 2: Calculate the Standard Error (SE)
# �
# �
# =
# �
# �
# =
# 8
# 50
# SE=
# n
# ​
#
# σ
# ​
#  =
# 50
# ​
#
# 8
# ​
#
#
# Step 3: Calculate the Margin of Error
# Margin of Error
# =
# �
# ×
# �
# �
# =
# 1.645
# ×
# 8
# 50
# Margin of Error=Z×SE=1.645×
# 50
# ​
#
# 8
# ​
#
#
# Step 4: Calculate the Confidence Interval
# CI
# =
# �
# ˉ
# ±
# Margin of Error
# CI=
# x
# ˉ
#  ±Margin of Error
#
# Calculation:
# Standard Error:
# �
# �
# =
# 8
# 50
# ≈
# 1.131
# SE=
# 50
# ​
#
# 8
# ​
#  ≈1.131
# Margin of Error:
# Margin of Error
# =
# 1.645
# ×
# 1.131
# ≈
# 1.86
# Margin of Error=1.645×1.131≈1.86
# Confidence Interval:
# CI
# =
# 65
# ±
# 1.86
# CI=65±1.86
# CI
# =
# [
# 63.14
# ,
# 66.86
# ]
# CI=[63.14,66.86]
# Interpretation:
# The 90% confidence interval for the true population mean is approximately between 63.14 and 66.86. This means we can be 90% confident that the true mean of the population lies within this interval. The sample mean of 65 lies well within this range, indicating that it is a plausible estimate of the population mean under these conditions.
