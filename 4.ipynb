# %% [markdown]
# Bayes's Theorem is a fundamental theorem in probability theory. It describes the probability of an event, based on prior knowledge of conditions that might be related to the event. The theorem is named after Thomas Bayes (1701–1761).
#
# Bayes's Theorem Formula:
# �
# (
# �
# ∣
# �
# )
# =
# �
# (
# �
# ∣
# �
# )
# ×
# �
# (
# �
# )
# �
# (
# �
# )
# P(A∣B)=
# P(B)
# P(B∣A)×P(A)
# ​
#
# Where:
#
# �
# (
# �
# ∣
# �
# )
# P(A∣B) is the probability of event A occurring, given that B is true.
# �
# (
# �
# ∣
# �
# )
# P(B∣A) is the probability of event B occurring, given that A is true.
# �
# (
# �
# )
# P(A) and
# �
# (
# �
# )
# P(B) are the probabilities of observing A and B independently of each other.
# Example:
# Let's consider a medical test for a specific disease.
#
# Suppose:
#
# The probability of having the disease (Event A) is 0.1% (or 0.001 in probability terms). This is
# �
# (
# �
# )
# P(A).
# The probability of testing positive if you have the disease (Event B given A) is 99%. This is
# �
# (
# �
# ∣
# �
# )
# P(B∣A).
# The probability of testing positive in general (Event B), which includes true positives and false positives, is 5%. This is
# �
# (
# �
# )
# P(B).
# Question: If a person tests positive, what is the probability that they actually have the disease?
#
# Using Bayes's Theorem:
#
# �
# (
# �
# ∣
# �
# )
# =
# �
# (
# �
# ∣
# �
# )
# ×
# �
# (
# �
# )
# �
# (
# �
# )
# P(A∣B)=
# P(B)
# P(B∣A)×P(A)
# ​
#
# �
# (
# �
# ∣
# �
# )
# =
# 0.99
# ×
# 0.001
# 0.05
# P(A∣B)=
# 0.05
# 0.99×0.001
# ​
#
# �
# (
# �
# ∣
# �
# )
# =
# 0.00099
# 0.05
# P(A∣B)=
# 0.05
# 0.00099
# ​
#
# �
# (
# �
# ∣
# �
# )
# =
# 0.0198
# P(A∣B)=0.0198 or 1.98%
# So, even if a person tests positive in this scenario, there is only a 1.98% chance that they actually have the disease. This example illustrates how Bayes's Theorem can significantly adjust our understanding of probabilities, especially in the context of conditional probabilities like medical testing. It highlights the importance of considering the base rate (prior probability) when interpreting the results of such tests.
